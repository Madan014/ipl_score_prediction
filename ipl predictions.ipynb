# %% [markdown]
# # import all the necessary libraries

# %%
import pandas as pd
import numpy as np
print("imported sucessfully")
# Out:
# imported sucessfully

# %%
delivery=pd.read_csv("E:\\6th semmmm\\ipl winlose prediction\\deliveries.csv")
matches=pd.read_csv("E:\\6th semmmm\\ipl winlose prediction\\matches.csv")
print(" imported dtaa suxcrssfully")
# Out:
#  imported dtaa suxcrssfully

# %%
# both the deliveries and the matches are interalted each others

# %%
# check the data shapes 
print(" delivery ",delivery.shape)
print(" matches ",matches.shape)
# Out:
#  delivery  (179078, 21)
#  matches  (756, 18)

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
matches.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
# to see the demo of the datas v
delivery.head()  # every ball detail is present in this datas
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# every rows reprenrt the detaioll of the one match from 2013 to 2017
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# this is thE DETAIL OF THE every match from the 209 to 2018
matches['Season'].value_counts()
# Out:
# Season
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2010    60
# IPL-2014    60
# IPL-2016    60
# IPL-2018    60
# IPL-2019    60
# IPL-2017    59
# IPL-2015    59
# IPL-2008    58
# IPL-2009    57
# Name: count, dtype: int64

# %% [markdown]
# # performance of the eda

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# inning 1 means 1 team , innings 2 means the opposite teams 
delivery.groupby(['match_id','inning']).sum()['total_runs']
# Out:
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#                    ...
# 11413     2         170
# 11414     1         155
#           2         162
# 11415     1         152
#           2         157
# Name: total_runs, Length: 1528, dtype: int64

# %%
# in 1 match there are 2 innings if we want to predict the ruins of inning 2 we havce to remove the inning 2 datas 
total_score_df=delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df.head()
# Out:
#    match_id  inning  total_runs
# 0         1       1         207
# 1         1       2         172
# 2         2       1         184
# 3         2       2         187
# 4         3       1         183

# %%
# fertch thee recortd of 1 inning from the total_score_dataframes 
total_score_df=total_score_df[total_score_df['inning']==1]

# %%
total_score_df.head()
# Out:
#    match_id  inning  total_runs
# 0         1       1         207
# 2         2       1         184
# 4         3       1         183
# 6         4       1         163
# 8         5       1         157

# %%
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# check the data is shaped ort not
total_score_df.shape
# Out:
# (756, 3)

# %%
matches.shape
# Out:
# (756, 18)

# %%
# now we have to merge the both datas
# this gives the total target from the batting teams 
match_df=matches.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df.head(5)
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # remove the unnecessary tean and clean the datasets

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
# the latest teams are 
teams=['Sunrisers Hyderabad',
       'Mumbai Indians',
       'Royal Challengers Bangalore',
       'Kolkata Knight Riders',
       'Kings XI Punjab',
       'Chennai Super Kings',
       'Rajasthan Royals',
       'Delhi Capitals'
]

# %%
match_df['team1']=match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2']=match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1']=match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2']=match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

print(" data clean sucessfully")
# Out:
#  data clean sucessfully

# %%
# filter the teams 
match_df=match_df[match_df['team1'].isin(teams)]
match_df=match_df[match_df['team2'].isin(teams)]
print(" sucessfully")
# Out:
#  sucessfully

# %%
match_df.shape
# Out:
# (641, 20)

# %% [markdown]
# # remove the dl applied teams --> means we have to fetch the data only if the rain is not occured

# %%
# there is 15 days the rain is occureddd and we have to skip- the rainy matches 
match_df['dl_applied'].value_counts()
# Out:
# dl_applied
# 0    626
# 1     15
# Name: count, dtype: int64

# %%
match_df=match_df[match_df['dl_applied']==0]

# %%
match_df.shape
# Out:
# (626, 20)

# %% [markdown]
# # feature extractionssss

# %%
match_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 6   7  IPL-2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7   8  IPL-2017     Indore  10-04-2017  Royal Challengers Bangalore
# 9  10  IPL-2017     Mumbai  12-04-2017          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4               Delhi Capitals  Royal Challengers Bangalore           bat
# 6               Mumbai Indians               Mumbai Indians         field
# 7              Kings XI Punjab  Royal Challengers Bangalore           bat
# 9               Mumbai Indians               Mumbai Indians         field
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
match_df=match_df[['match_id','city','winner','total_runs']]
match_df.head()
# Out:
#    match_id       city                       winner  total_runs
# 0         1  Hyderabad          Sunrisers Hyderabad         207
# 4         5  Bangalore  Royal Challengers Bangalore         157
# 6         7     Mumbai               Mumbai Indians         178
# 7         8     Indore              Kings XI Punjab         148
# 9        10     Mumbai               Mumbai Indians         158

# %% [markdown]
# # to make the records by ball to balll we have to do this

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
match_df.merge(delivery,on='match_id')
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 0              1  Hyderabad  Sunrisers Hyderabad           207       1
# 1              1  Hyderabad  Sunrisers Hyderabad           207       1
# 2              1  Hyderabad  Sunrisers Hyderabad           207       1
# 3              1  Hyderabad  Sunrisers Hyderabad           207       1
# 4              1  Hyderabad  Sunrisers Hyderabad           207       1
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
delivery_df=match_df.merge(delivery,on='match_id')

# %%
delivery_df.head()
# Out:
#    match_id       city               winner  total_runs_x  inning  \
# 0         1  Hyderabad  Sunrisers Hyderabad           207       1
# 1         1  Hyderabad  Sunrisers Hyderabad           207       1
# 2         1  Hyderabad  Sunrisers Hyderabad           207       1
# 3         1  Hyderabad  Sunrisers Hyderabad           207       1
# 4         1  Hyderabad  Sunrisers Hyderabad           207       1
#
#           batting_team                 bowling_team  over  ball    batsman  \
# 0  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner
# 1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2  DA Warner
# 2  Sunrisers Hyderabad  Royal Challengers Bangalore     1     3  DA Warner
# 3  Sunrisers Hyderabad  Royal Challengers Bangalore     1     4  DA Warner
# 4  Sunrisers Hyderabad  Royal Challengers Bangalore     1     5  DA Warner
#
#    ... bye_runs legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
# now filter the ining 1 data only
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df.shape
# Out:
# (72413, 24)

# %%
# warning messages 
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... bye_runs legbye_runs  noball_runs  penalty_runs  \
# 125       CH Gayle  ...        0           0            0             0
# ...

# %%
# find the total runs in the every balls --> current runn  ( by cumulative frequency counts )
delivery_df.groupby('match_id')['total_runs_y'].cumsum()   # df['A'].cumsum()           #$.cumsum()['total_runs_y']
# Out:
# 125         1
# 126         1
# 127         1
# 128         3
# 129         7
#          ...
# 149573    152
# 149574    154
# 149575    155
# 149576    157
# 149577    157
# Name: total_runs_y, Length: 72413, dtype: int64

# %%
delivery_df['current_score']=delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df.head(10)
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
# 130         1  Hyderabad  Sunrisers Hyderabad           207       2
# 131         1  Hyderabad  Sunrisers Hyderabad           207       2
# 132         1  Hyderabad  Sunrisers Hyderabad           207       2
# 133         1  Hyderabad  Sunrisers Hyderabad           207       2
# 134         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# ...

# %%
# runs left to win the matchs  --> we have to subtract current run from the targets in eacxgh of the balls 

delivery_df['total_runs_x']-delivery_df['current_score']
# Out:
# 125       206
# 126       206
# 127       206
# 128       204
# 129       200
#          ...
# 149573      0
# 149574     -2
# 149575     -3
# 149576     -5
# 149577     -5
# Length: 72413, dtype: int64

# %%
delivery_df.tail()
# Out:
#         match_id       city          winner  total_runs_x  inning  \
# 149573     11415  Hyderabad  Mumbai Indians           152       2
# 149574     11415  Hyderabad  Mumbai Indians           152       2
# 149575     11415  Hyderabad  Mumbai Indians           152       2
# 149576     11415  Hyderabad  Mumbai Indians           152       2
# 149577     11415  Hyderabad  Mumbai Indians           152       2
#
#                batting_team    bowling_team  over  ball    batsman  ...  \
# 149573  Chennai Super Kings  Mumbai Indians    20     2  RA Jadeja  ...
# 149574  Chennai Super Kings  Mumbai Indians    20     3  SR Watson  ...
# 149575  Chennai Super Kings  Mumbai Indians    20     4  SR Watson  ...
# 149576  Chennai Super Kings  Mumbai Indians    20     5  SN Thakur  ...
# 149577  Chennai Super Kings  Mumbai Indians    20     6  SN Thakur  ...
#
#        legbye_runs noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# make the runs left columns 
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... noball_runs penalty_runs  batsman_runs  extra_runs  \
# 125       CH Gayle  ...           0            0             1           0
# ...

# %% [markdown]
# # make the columns for the total balls lefts

# %%
# formulas --> 126  - no_of_over*6 + number off balls in overrs 

delivery_df['balls_left']=126-(delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df.sample(2)
# Out:
#         match_id     city               winner  total_runs_x  inning  \
# 123601      7903  Kolkata  Sunrisers Hyderabad           145       2
# 73149        386  Chennai       Mumbai Indians           148       2
#
#                batting_team           bowling_team  over  ball        batsman  \
# 123601  Sunrisers Hyderabad  Kolkata Knight Riders    11     1  KS Williamson
# 73149   Chennai Super Kings         Mumbai Indians     3     5     MEK Hussey
#
#         ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# 123601  ...            0            0           0             0
# 73149   ...            0            0           0             0
#
#         player_dismissed  dismissal_kind  fielder  current_score  runs_left  \
# 123601               NaN             NaN      NaN             66         79
# 73149                NaN             NaN      NaN             14        134
#
#         balls_left
# 123601          59
# 73149          103
#
# [2 rows x 27 columns]

# %% [markdown]
# # to find the player dismished

# %%
# if player dismissed there is player name else there is NAN value
delivery_df['player_dismissed'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 72413 entries, 125 to 149577
# Series name: player_dismissed
# Non-Null Count  Dtype
# --------------  -----
# 3553 non-null   object
# dtypes: object(1)
# memory usage: 1.1+ MB

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna('0')
print("filled sucessfully")
# Out:
# filled sucessfully

# %%
delivery_df.sample(1)
# Out:
#        match_id    city          winner  total_runs_x  inning  \
# 78958       417  Mumbai  Mumbai Indians           194       2
#
#                       batting_team    bowling_team  over  ball   batsman  ...  \
# 78958  Royal Challengers Bangalore  Mumbai Indians     4     3  CH Gayle  ...
#
#       penalty_runs batsman_runs  extra_runs  total_runs_y  player_dismissed  \
# 78958            0            0           0             0                 0
#
#        dismissal_kind  fielder  current_score  runs_left  balls_left
# 78958             NaN      NaN             25        169          99
#
# [1 rows x 27 columns]

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x : x if x=='0' else '1')
print(" sucessfully")
# Out:
#  sucessfully

# %%
# convert the player dismissed in to the integer types 
delivery_df['player_dismissed']=delivery_df['player_dismissed'].astype('int')

# %%
delivery_df['player_dismissed'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 72413 entries, 125 to 149577
# Series name: player_dismissed
# Non-Null Count  Dtype
# --------------  -----
# 72413 non-null  int32
# dtypes: int32(1)
# memory usage: 848.6 KB

# %% [markdown]
# # calculkate the total wicket remaining

# %%
wickets=delivery_df.groupby('match_id')['player_dismissed'].cumsum().values

# %%
wickets
# Out:
# array([0, 0, 0, ..., 6, 6, 7])

# %%
delivery_df['wickets']=10-wickets

# %%
# to check whether it is working properly or nots 
delivery_df[delivery_df['player_dismissed']==1]
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 160            1  Hyderabad  Sunrisers Hyderabad           207       2
# 165            1  Hyderabad  Sunrisers Hyderabad           207       2
# 199            1  Hyderabad  Sunrisers Hyderabad           207       2
# 206            1  Hyderabad  Sunrisers Hyderabad           207       2
# 211            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149519     11415  Hyderabad       Mumbai Indians           152       2
# 149533     11415  Hyderabad       Mumbai Indians           152       2
# 149567     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... batsman_runs extra_runs  total_runs_y  \
# 125       CH Gayle  ...            1          0             1
# ...

# %% [markdown]
# # calculate rthe current runs rates

# %%
# current_eruns_rates=runs/over
delivery_df['crr']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])
print(" sucessfully")
# Out:
#  sucessfully

# %%
delivery_df.sample(1)
# Out:
#        match_id        city           winner  total_runs_x  inning  \
# 15953        97  Chandigarh  Kings XI Punjab           221       2
#
#            batting_team     bowling_team  over  ball  batsman  ... extra_runs  \
# 15953  Rajasthan Royals  Kings XI Punjab    18     3  M Rawat  ...          0
#
#       total_runs_y  player_dismissed  dismissal_kind  fielder  current_score  \
# 15953            4                 0             NaN      NaN            165
#
#        runs_left  balls_left  wickets       crr
# 15953         56          15        5  9.428571
#
# [1 rows x 29 columns]

# %%
# vrequired run rates 
delivery_df['rrr']=(delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
delivery_df.sample()
# Out:
#        match_id       city            winner  total_runs_x  inning  \
# 21809       126  Cape Town  Rajasthan Royals           150       2
#
#                 batting_team      bowling_team  over  ball    batsman  ...  \
# 21809  Kolkata Knight Riders  Rajasthan Royals    12     3  SB Bangar  ...
#
#       total_runs_y player_dismissed  dismissal_kind  fielder  current_score  \
# 21809            1                0             NaN      NaN             75
#
#        runs_left  balls_left  wickets       crr       rrr
# 21809         75          51        6  6.521739  8.823529
#
# [1 rows x 30 columns]

# %% [markdown]
# # make the result columns

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0
print(" makes functions sucessfully")
# Out:
#  makes functions sucessfully

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)

# %%
delivery_df.sample(5)
# Out:
#         match_id       city                       winner  total_runs_x  \
# 60120        317  Bangalore        Kolkata Knight Riders           165
# 60632        319     Mumbai               Mumbai Indians           197
# 97335        503  Hyderabad          Sunrisers Hyderabad           160
# 55019        285     Jaipur          Chennai Super Kings           196
# 120936       632     Raipur  Royal Challengers Bangalore           138
#
#         inning                 batting_team                 bowling_team  \
# 60120        2  Royal Challengers Bangalore        Kolkata Knight Riders
# 60632        2             Rajasthan Royals               Mumbai Indians
# 97335        2          Sunrisers Hyderabad  Royal Challengers Bangalore
# 55019        2             Rajasthan Royals          Chennai Super Kings
# 120936       2  Royal Challengers Bangalore             Delhi Daredevils
#
#         over  ball     batsman  ... player_dismissed dismissal_kind  fielder  \
# ...

# %% [markdown]
# # filter the only specific columns from the entrire dataframes

# %%
final_df=delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df.shape
# Out:
# (72413, 10)

# %%
final_df.head()
# Out:
#                     batting_team         bowling_team       city  runs_left  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        206
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        206
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        206
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        204
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        200
#
#      balls_left  wickets  total_runs_x  crr        rrr  result
# 125         119       10           207  6.0  10.386555       0
# 126         118       10           207  3.0  10.474576       0
# 127         117       10           207  2.0  10.564103       0
# 128         116       10           207  4.5  10.551724       0
# 129         115       10           207  8.4  10.434783       0

# %%
final_df[final_df['result']==1].sample(5)
# Out:
#                        batting_team                 bowling_team       city  \
# 97377           Sunrisers Hyderabad  Royal Challengers Bangalore  Hyderabad
# 116086               Mumbai Indians  Royal Challengers Bangalore     Mumbai
# 8355               Rajasthan Royals              Kings XI Punjab     Jaipur
# 47517   Royal Challengers Bangalore              Deccan Chargers     Mumbai
# 72219         Kolkata Knight Riders          Chennai Super Kings    Chennai
#
#         runs_left  balls_left  wickets  total_runs_x        crr       rrr  \
# 97377          81          56       10           160   7.406250  8.678571
# 116086        138          93        9           170   7.111111  8.903226
# 8355          153         107        9           166   6.000000  8.579439
# 47517          56          91       10            82   5.379310  3.692308
# 72219          79          54        9           190  10.090909  8.777778
#
#         result
# 97377        1
# 116086       1
# ...

# %%
# shufflings the data it can develop the bias 
final_df=final_df.sample(final_df.shape[0])

# %% [markdown]
# # data cleanings

# %%
# remove all the null values 
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            832
# runs_left         0
# balls_left        0
# wickets           0
# total_runs_x      0
# crr               0
# rrr               7
# result            0
# dtype: int64

# %%
# remove the null values from the city teams 
final_df.dropna(inplace=True)

# %%
# cleaning datas 
final_df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
# remove the final ball beacuse it occurs the error of the infinity problems 
final_df=final_df[final_df['balls_left']!=0]

# %%
# it solve the peobnlems of the infinity 
final_df[final_df['balls_left']==0]
# Out:
# Empty DataFrame
# Columns: [batting_team, bowling_team, city, runs_left, balls_left, wickets, total_runs_x, crr, rrr, result]
# Index: []

# %%
final_df.head()
# Out:
#                batting_team           bowling_team        city  runs_left  \
# 98827      Rajasthan Royals        Kings XI Punjab  Chandigarh        114
# 118036      Kings XI Punjab  Kolkata Knight Riders     Kolkata        123
# 121877      Kings XI Punjab       Delhi Daredevils      Mohali        114
# 74683   Sunrisers Hyderabad       Delhi Daredevils       Delhi         45
# 104611     Rajasthan Royals    Chennai Super Kings   Ahmedabad         20
#
#         balls_left  wickets  total_runs_x        crr        rrr  result
# 98827           59        7           179   6.393443  11.593220       0
# 118036          79        7           164   6.000000   9.341772       0
# 121877          99        9           172  16.571429   6.909091       1
# 74683           36        6           114   4.928571   7.500000       1
# 104611          30       10           156   9.066667   4.000000       1

# %%
# save this csv file into the local files 
final_df.to_csv("E:\\6th semmmm\\ml datas\\ipl_clean.csv",index=False)
print(" saves the dtaa sucessfully")
# Out:
#  saves the dtaa sucessfully

# %% [markdown]
# # feature engineering

# %%
# ytrain test splits
x=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]

# %%
x.head(1)
# Out:
#            batting_team     bowling_team        city  runs_left  balls_left  \
# 98827  Rajasthan Royals  Kings XI Punjab  Chandigarh        114          59
#
#        wickets  total_runs_x       crr       rrr
# 98827        7           179  6.393443  11.59322

# %%
y.head(1)
# Out:
# 98827    0
# Name: result, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (57073, 9) (14269, 9)
# (57073,) (14269,)

# %%
x_train.head(2)
# Out:
#                       batting_team     bowling_team     city  runs_left  \
# 34528          Chennai Super Kings  Deccan Chargers  Chennai        104
# 7872   Royal Challengers Bangalore   Mumbai Indians   Mumbai        148
#
#        balls_left  wickets  total_runs_x       crr        rrr
# 34528          44        5           190  6.789474  14.181818
# 7872          104       10           165  6.375000   8.538462

# %% [markdown]
# # one hot encoding on the batting_teram,bowling_team and city

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf=ColumnTransformer([
    ('trf1',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')
print(" transform columns sucessfully")
# Out:
#  transform columns sucessfully

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
print(" imported sucessfully")
# Out:
#  imported sucessfully

# %% [markdown]
# # logistic regressions algorithm

# %%
pipe_logistic=Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])
print(" make the pipeline sucessfully")
# Out:
#  make the pipeline sucessfully

# %% [markdown]
# # naive bayes algorithms

# %%
from sklearn.naive_bayes import GaussianNB
pipe_naive_bayes=Pipeline(steps=[
    ('step1',trf),
    ('step2',GaussianNB())
])
print(" make the pipeline sucessfully for the guassina naive bayes ")
# Out:
#  make the pipeline sucessfully for the guassina naive bayes

# %% [markdown]
# # random forest algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
pipe_random_forest=Pipeline(steps=[
    ('step1',trf),
    ('step2',RandomForestClassifier())
])
print(" make the pipeline sucessfully for the random forests ")
# Out:
#  make the pipeline sucessfully for the random forests

# %%
# fit both the pipelines 
pipe_random_forest.fit(x_train,y_train)
pipe_logistic.fit(x_train,y_train)
pipe_naive_bayes.fit(x_train,y_train)
print("fit both the pipelines")
# Out:
# fit both the pipelines

# %% [markdown]
# # check the accuracy of the both algorithms

# %%
y_pred_logistic=pipe_logistic.predict(x_test)
y_pred_naive=pipe_naive_bayes.predict(x_test)
y_pred_random_forest=pipe_random_forest.predict(x_test)
print(" sucess")
# Out:
#  sucess

# %%
from sklearn.metrics import accuracy_score
print("Naive Bayes : ",accuracy_score(y_test,y_pred_naive))
print("logistic Regression : ",accuracy_score(y_test,y_pred_logistic))
print("Random Forest Algorithm : ",accuracy_score(y_test,y_pred_random_forest))
# Out:
# Naive Bayes :  0.7186207863199944
# logistic Regression :  0.8074847571658841
# Random Forest Algorithm :  0.9988086060691008

# %% [markdown]
# # predicts

# %%
pipe_logistic.predict(x_test)[3]
# Out:
# 1

# %%
# dump the model using puickle
import pickle
pickle.dump(pipe_logistic,open('E:\\6th semmmm\\ml datas\\logistic.pkl','wb'))
pickle.dump(pipe_naive_bayes,open("E:\\6th semmmm\\ml datas\\naive_bayes.pkl",'wb'))
pickle.dump(pipe_random_forest,open("E:\\6th semmmm\\ml datas\\random_forest.pkl",'wb'))
print(" saves all the models sucessfully")
# Out:
#  saves all the models sucessfully

# %%
final_df['city'].unique()
# Out:
# array(['Chandigarh', 'Kolkata', 'Mohali', 'Delhi', 'Ahmedabad', 'Mumbai',
#        'Jaipur', 'Bangalore', 'Chennai', 'Hyderabad', 'Visakhapatnam',
#        'Bengaluru', 'Dharamsala', 'Indore', 'Johannesburg', 'Cuttack',
#        'Ranchi', 'Raipur', 'Cape Town', 'Durban', 'Centurion', 'Sharjah',
#        'Kimberley', 'Port Elizabeth', 'Abu Dhabi', 'Pune', 'East London',
#        'Bloemfontein', 'Nagpur'], dtype=object)
